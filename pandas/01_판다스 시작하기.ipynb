# %%
'import pandas as pd

# %%
df = pd.read_csv('pandas/data/gapminder.tsv',sep = '\t')
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['country'])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
df.shape
# Out:
# (1704, 6)

# %%
df.columns[:2]
# Out:
# Index(['country', 'continent'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1704 entries, 0 to 1703
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   country    1704 non-null   object
#  1   continent  1704 non-null   object
#  2   year       1704 non-null   int64
#  3   lifeExp    1704 non-null   float64
#  4   pop        1704 non-null   int64
#  5   gdpPercap  1704 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 80.0+ KB

# %%
import time
time.time()
# Out:
# 1664425137.2639241

# %%
df[ [ 'country', 'continent', 'year'] ]
# Out:
#           country continent  year
# 0     Afghanistan      Asia  1952
# 1     Afghanistan      Asia  1957
# 2     Afghanistan      Asia  1962
# 3     Afghanistan      Asia  1967
# 4     Afghanistan      Asia  1972
# ...           ...       ...   ...
# 1699     Zimbabwe    Africa  1987
# 1700     Zimbabwe    Africa  1992
# 1701     Zimbabwe    Africa  1997
# 1702     Zimbabwe    Africa  2002
# 1703     Zimbabwe    Africa  2007
#
# [1704 rows x 3 columns]

# %%
df.set_index('continent')
# Out:
#                country  year  lifeExp       pop   gdpPercap
# continent
# Asia       Afghanistan  1952   28.801   8425333  779.445314
# Asia       Afghanistan  1957   30.332   9240934  820.853030
# Asia       Afghanistan  1962   31.997  10267083  853.100710
# Asia       Afghanistan  1967   34.020  11537966  836.197138
# Asia       Afghanistan  1972   36.088  13079460  739.981106
# ...                ...   ...      ...       ...         ...
# Africa        Zimbabwe  1987   62.351   9216418  706.157306
# Africa        Zimbabwe  1992   60.377  10704340  693.420786
# Africa        Zimbabwe  1997   46.809  11404948  792.449960
# Africa        Zimbabwe  2002   39.989  11926563  672.038623
# Africa        Zimbabwe  2007   43.487  12311143  469.709298
#
# [1704 rows x 5 columns]

# %%
df.iloc[0]
# Out:
# country      Afghanistan
# continent           Asia
# year                1952
# lifeExp           28.801
# pop              8425333
# gdpPercap     779.445314
# Name: 0, dtype: object

# %%
df.iloc[99]
# Out:
# country      Bangladesh
# continent          Asia
# year               1967
# lifeExp          43.453
# pop            62821884
# gdpPercap    721.186086
# Name: 99, dtype: object

# %%
#마지막 행 데이터 추출하기
number_of_rows = df.shape[0]
last_row_index = number_of_rows -1
df.loc[last_row_index]
# Out:
# country        Zimbabwe
# continent        Africa
# year               2007
# lifeExp          43.487
# pop            12311143
# gdpPercap    469.709298
# Name: 1703, dtype: object

# %%
df.loc[[0,1,5,10]]
# Out:
#         country continent  year  lifeExp       pop   gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934  820.853030
# 5   Afghanistan      Asia  1977   38.438  14880372  786.113360
# 10  Afghanistan      Asia  2002   42.129  25268405  726.734055

# %%
df.loc[ 0 : 5 ]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360

# %%
df.loc[5 : 0 : -1]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314

# %%
df.iloc[0:5]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
df.iloc[5 : 0 : -1]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 5  Afghanistan      Asia  1977   38.438  14880372  786.113360
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030

# %%
df.groupby('year')

# %%
df['year'].unique()
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007], dtype=int64)

# %%
df[df['year'] == 1952]
# Out:
#                  country continent  year  lifeExp       pop    gdpPercap
# 0            Afghanistan      Asia  1952   28.801   8425333   779.445314
# 12               Albania    Europe  1952   55.230   1282697  1601.056136
# 24               Algeria    Africa  1952   43.077   9279525  2449.008185
# 36                Angola    Africa  1952   30.015   4232095  3520.610273
# 48             Argentina  Americas  1952   62.485  17876956  5911.315053
# ...                  ...       ...   ...      ...       ...          ...
# 1644             Vietnam      Asia  1952   40.412  26246839   605.066492
# 1656  West Bank and Gaza      Asia  1952   43.160   1030585  1515.592329
# 1668         Yemen, Rep.      Asia  1952   32.548   4963829   781.717576
# 1680              Zambia    Africa  1952   42.038   2672000  1147.388831
# 1692            Zimbabwe    Africa  1952   48.451   3080907   406.884115
#
# [142 rows x 6 columns]

# %%
df.groupby('year')['lifeExp'].mean()
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
df2 = df.groupby(['year','continent']).sum()
df2
# Out:
#                    lifeExp         pop      gdpPercap
# year continent
# 1952 Africa     2035.04600   237640501   65133.768223
#      Americas   1331.99600   345152446  101976.563805
#      Asia       1528.37500  1395357351  171450.972133
#      Europe     1932.25500   418120846  169831.723043
#      Oceania     138.51000    10686006   20596.171300
# 1957 Africa     2145.85000   264837738   72032.275237
#      Americas   1399.00700   386953916  115401.093329
#      Asia       1627.51196  1562780599  190995.187018
#      Europe     2001.09200   437890351  208890.384478
#      Oceania     140.59000    11941976   23197.044910
# 1962 Africa     2252.61100   296516865   83100.098892
#      Americas   1459.96900   433270254  122538.546760
#      Asia       1701.58636  1696357182  189069.197618
#      Europe     2056.17700   460355155  250964.604429
#      Oceania     142.17000    13283518   25392.904860
# 1967 Africa     2357.39600   335289489  106618.917645
# ...

# %%
df2.reset_index()
# Out:
#     year continent     lifeExp         pop      gdpPercap
# 0   1952    Africa  2035.04600   237640501   65133.768223
# 1   1952  Americas  1331.99600   345152446  101976.563805
# 2   1952      Asia  1528.37500  1395357351  171450.972133
# 3   1952    Europe  1932.25500   418120846  169831.723043
# 4   1952   Oceania   138.51000    10686006   20596.171300
# 5   1957    Africa  2145.85000   264837738   72032.275237
# 6   1957  Americas  1399.00700   386953916  115401.093329
# 7   1957      Asia  1627.51196  1562780599  190995.187018
# 8   1957    Europe  2001.09200   437890351  208890.384478
# 9   1957   Oceania   140.59000    11941976   23197.044910
# 10  1962    Africa  2252.61100   296516865   83100.098892
# 11  1962  Americas  1459.96900   433270254  122538.546760
# 12  1962      Asia  1701.58636  1696357182  189069.197618
# 13  1962    Europe  2056.17700   460355155  250964.604429
# 14  1962   Oceania   142.17000    13283518   25392.904860
# ...

# %%
df.groupby('continent')['country'].nunique()#빈도수
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
year_life_expectancy = df.groupby('year')['lifeExp'].mean()
year_life_expectancy
# Out:
# year
# 1952    49.057620
# 1957    51.507401
# 1962    53.609249
# 1967    55.678290
# 1972    57.647386
# 1977    59.570157
# 1982    61.533197
# 1987    63.212613
# 1992    64.160338
# 1997    65.014676
# 2002    65.694923
# 2007    67.007423
# Name: lifeExp, dtype: float64

# %%
year_life_expectancy.plot()
# Out:
# <AxesSubplot:xlabel='year'>
